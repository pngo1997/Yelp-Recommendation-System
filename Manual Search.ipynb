# %%
#Mount my Google Drive
from google.colab import drive
drive.mount("/content/drive")
import os
directory = '/content/drive/My Drive/CSC575 Final Project'
os.chdir(directory)

#Ensure the files are there (in the folder)
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/CSC575 Final Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
from google.colab import files
#Text preprocessing.
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
#Warnings.
import warnings
warnings.filterwarnings("ignore")
#Geo location.
import folium
from geopy.geocoders import Nominatim
#String process.
import ast
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## **Task 1: Business Recommendation by Table Lookup**

# %%
businessData_original = pd.read_csv('businesses.csv', sep='\t', encoding = 'ISO-8859-1')
print(f'Business data: Row - {businessData_original.shape[0]} | Column - {businessData_original.shape[1]}')
# Out:
# Business data: Row - 100000 | Column - 15

# %%
businessData_original.head()
# Out:
#    Unnamed: 0             business_id                      name  \
# 0           0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1           1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2           2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3           3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4           4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %% [markdown]
# #### **Convert 'categories' column for query search. For example 'Local Services' will become 'LocalServices'.**

# %%
#Make a copy.
businessData = businessData_original
def processCategories(x):
  '''Convert column for query search.'''

  if isinstance(x, str):
    return ', '.join(category.replace(' ', '') for category in x.split(','))
  else:
    return np.nan
businessData['categories'] = businessData['categories'].apply(processCategories)
businessData.head()
# Out:
#    Unnamed: 0             business_id                      name  \
# 0           0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1           1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2           2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3           3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4           4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, TraditionalChineseMedicine, Naturopat...
# 1  ShippingCenters, LocalServices, Notaries, Mail...
# 2  DepartmentStores, Shopping, Fashion, Home&Gard...
# 3  Restaurants, Food, BubbleTea, Coffee&Tea, Bake...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %% [markdown]
# ### **Recommendation function.**

# %%
def getRec(query, numRec=100000, data=businessData):
    '''Get recommendation places based on a query.
    Accepting template | Best Categories1 Categories2 in City that have/has/are Attribute
    'Best' and Categories1 are optional.'''

    queryList = query.split(" ")

    establishmentType_List = None
    city = None
    attribute = None

    #If the query starts with 'Best'.
    if queryList[0] == 'Best':
        establishment_endIndex = queryList.index('in')
        establishmentType_List = queryList[1 : establishment_endIndex]

    #Query starts with business type.
    else:
        establishment_endIndex = queryList.index('in')
        establishmentType_List = queryList[0 : establishment_endIndex]

    #Iterate through queryList to extract city and services.
    for i, word in enumerate(queryList):
        if word == 'in' and i + 1 < len(queryList):
            #Extract the city after 'in'.
            city_startIndex = i + 1
            city_endIndex = queryList.index('that') if 'that' in queryList else len(queryList)
            city = ' '.join(queryList[city_startIndex : city_endIndex]).title()
            print("City:", city)

        #If services included in the query.
        elif word == 'that' and i + 2 < len(queryList):
            #Extract the services after 'that'.
            attribute = ' '.join(queryList[i + 2:])
            print("Services:", attribute)

    #Capitalize to look up.
    establishmentType_List = [estType.lower() for estType in establishmentType_List]
    print("Establishment Types:", establishmentType_List)

    if establishmentType_List or city or attribute:
      #Get city & 1st category.
      queryRes = data[(data['city'] == city) & data['categories'].str.lower().str.contains(establishmentType_List[0], na=False)]
      #Get attribute.
      if attribute is not None:
        queryRes = queryRes[data['attributes'].astype(str).str.contains(fr"'{attribute}': 'True'")]

      #Get 2nd category.
      if len(establishmentType_List) > 1:
        queryRes = queryRes[data['categories'].str.lower().str.contains(establishmentType_List[1], na=False)]

      if 'Best' in queryList:
        #If 'Best' is in the query, filter by stars > 4.0
        queryRes = queryRes[queryRes['stars'] > 4.0]

      #Sorted according to the 'stars', then 'review_count', then 'name' (alphabetically).
      #Also extract 'latitude' & 'longitude' for geo map.
      queryRes = queryRes.sort_values(by=['stars', 'review_count', 'name'],
                 ascending=[False, False, True]).head(numRec)[['stars', 'name', 'review_count', 'categories', 'latitude', 'longitude']]

      return queryRes, city

# %% [markdown]
# #### **Best restaurants in Toronto --> No Toronto City entry. Have double check on Kaggle.**

# %%
queryRes_1, city = getRec('Best restaurants in Toronto', 5)
display(queryRes_1)
# Out:
# City: Toronto
# Establishment Types: ['restaurants']
# Empty DataFrame
# Columns: [stars, name, review_count, categories, latitude, longitude]
# Index: []

# %%
#Plain query.
queryPlain_1 = businessData_original[
    (businessData_original['city'] == 'Toronto') &
    (businessData_original['categories'].str.contains('Restaurants'))]

queryPlain_1 = queryPlain_1.sort_values(by=['stars', 'review_count', 'name'],
               ascending=[False, False, True]).head(5)[['stars', 'name', 'review_count', 'categories']]
queryPlain_1
# Out:
# Empty DataFrame
# Columns: [stars, name, review_count, categories]
# Index: []

# %% [markdown]
# #### **Best Chinese restaurants in Las Vegas --> No Las Vegas City entry. . Have double check on Kaggle.**

# %%
queryRes_2, city = getRec('Best Chinese restaurants in Las Vegas', 5)
display(queryRes_2)
# Out:
# City: Las Vegas
# Establishment Types: ['chinese', 'restaurants']
# Empty DataFrame
# Columns: [stars, name, review_count, categories, latitude, longitude]
# Index: []

# %%
#Plain query.
queryPlain_2 = businessData_original[
    (businessData_original['city'] == 'Las Vegas') &
    (businessData_original['categories'].str.contains('Restaurants', na=False) &
    (businessData_original['categories'].str.contains('Chinese', na=False)))]

queryPlain_2 = queryPlain_2.sort_values(by=['stars', 'review_count', 'name'],
               ascending=[False, False, True]).head(5)[['stars', 'name', 'review_count', 'categories']]
display(queryPlain_2)
# Out:
# Empty DataFrame
# Columns: [stars, name, review_count, categories]
# Index: []

# %% [markdown]
# #### **Pubs in Philadelphia that are WheelchairAccessible.**

# %%
queryRes_3, city = getRec('Pubs in Philadelphia that are WheelchairAccessible', 5)
display(queryRes_3)
# Out:
# City: Philadelphia
# Services: WheelchairAccessible
# Establishment Types: ['pubs']
#        stars                       name  review_count  \
# 94471    4.5                  Bar Hygge           387
# 53651    4.5   Glory Beer Bar & Kitchen           203
# 79730    4.5  Love City Brewing Company           162
# 1106     4.5           Chase's Hop Shop           116
# 78757    4.5     Original 13 Ciderworks            65
#
#                                               categories   latitude  longitude
# 94471  Food, Restaurants, Breweries, ComfortFood, Bre...  39.967125 -75.166124
# 53651  American(New), LocalFlavor, Bars, Restaurants,...  39.948179 -75.143545
# 79730  Brewpubs, Breweries, Nightlife, Bars, Food, Ba...  39.960310 -75.155415
# 1106   ChickenWings, Nightlife, Bars, Delis, Food, Be...  40.060386 -75.084590
# 78757  American(Traditional), Food, Restaurants, Bars...  39.974598 -75.140215

# %%
queryPlain_3 = businessData[
    (businessData['city'] == 'Philadelphia') &
    (businessData['categories'].str.contains('pubs', case=False)) &
    businessData['attributes'].astype(str).str.contains(r"'WheelchairAccessible': 'True'")]

queryPlain_3 = queryPlain_3.sort_values(by=['stars', 'review_count', 'name'],
               ascending=[False, False, True]).head(5)[['stars', 'name', 'review_count', 'categories', 'attributes', 'city']]
display(queryPlain_3)
# Out:
#        stars                       name  review_count  \
# 94471    4.5                  Bar Hygge           387
# 53651    4.5   Glory Beer Bar & Kitchen           203
# 79730    4.5  Love City Brewing Company           162
# 1106     4.5           Chase's Hop Shop           116
# 78757    4.5     Original 13 Ciderworks            65
#
#                                               categories  \
# 94471  Food, Restaurants, Breweries, ComfortFood, Bre...
# 53651  American(New), LocalFlavor, Bars, Restaurants,...
# 79730  Brewpubs, Breweries, Nightlife, Bars, Food, Ba...
# 1106   ChickenWings, Nightlife, Bars, Delis, Food, Be...
# 78757  American(Traditional), Food, Restaurants, Bars...
#
#                                               attributes          city
# 94471  {'DogsAllowed': 'False', 'WheelchairAccessible...  Philadelphia
# 53651  {'OutdoorSeating': 'True', 'RestaurantsTakeOut...  Philadelphia
# 79730  {'BusinessAcceptsBitcoin': 'False', 'BikeParki...  Philadelphia
# 1106   {'RestaurantsReservations': 'False', 'Alcohol'...  Philadelphia
# 78757  {'BikeParking': 'True', 'RestaurantsDelivery':...  Philadelphia

# %% [markdown]
# #### **Best Chinese restaurants in Philadelphia.**

# %%
queryRes_4, city = getRec('Best Chinese restaurants in Philadelphia', 5)
display(queryRes_4)
# Out:
# City: Philadelphia
# Establishment Types: ['chinese', 'restaurants']
#        stars                      name  review_count  \
# 41818    5.0  Far East Chinese Cuisine            28
# 67395    5.0             House of Chen            10
# 23052    5.0             Peking Garden             9
# 63522    5.0              Paradise Inn             8
# 12494    5.0               Jade Palace             6
#
#                                         categories   latitude  longitude
# 41818              Cantonese, Chinese, Restaurants  40.019695 -75.174272
# 67395                         Restaurants, Chinese  39.955173 -75.155511
# 23052  American(Traditional), Chinese, Restaurants  39.986448 -75.155695
# 63522                         Chinese, Restaurants  39.974099 -75.181294
# 12494                         Restaurants, Chinese  39.926865 -75.154242

# %%
#Plain query.
queryPlain_4 = businessData_original[
    (businessData_original['city'] == 'Philadelphia') &
    (businessData_original['categories'].str.contains('Restaurants', na=False) &
    (businessData_original['categories'].str.contains('Chinese', na=False)))]

queryPlain_4 = queryPlain_4.sort_values(by=['stars', 'review_count', 'name'],
               ascending=[False, False, True]).head(5)[['stars', 'name', 'review_count', 'categories']]
display(queryPlain_4)
# Out:
#        stars                      name  review_count  \
# 41818    5.0  Far East Chinese Cuisine            28
# 67395    5.0             House of Chen            10
# 23052    5.0             Peking Garden             9
# 63522    5.0              Paradise Inn             8
# 12494    5.0               Jade Palace             6
#
#                                         categories
# 41818              Cantonese, Chinese, Restaurants
# 67395                         Restaurants, Chinese
# 23052  American(Traditional), Chinese, Restaurants
# 63522                         Chinese, Restaurants
# 12494                         Restaurants, Chinese

# %% [markdown]
# ### **Follow-up from the previous query.**
# #### **Business hours for "DeSandro on Main" in Philadelphia for Friday.**

# %%
desandroEst = businessData_original[(businessData_original['city'] == 'Philadelphia') &
                                    (businessData_original['name'] == 'DeSandro on Main')]
display(desandroEst)

desandroEst_hoursString = desandroEst['hours'].iloc[0]
print(f"DeSandro on Main full hours: {desandroEst_hoursString}")
desandroEst_hoursDict = ast.literal_eval(desandroEst_hoursString) if isinstance(desandroEst_hoursString, str) else {}
fridayHours = desandroEst_hoursDict.get('Friday', 'Placeholder')
print(f"DeSandro on Main Friday hours: {fridayHours}")
# Out:
#     Unnamed: 0             business_id              name       address  \
# 31          31  Mjboz24M9NlBeiOJKLEd_Q  DeSandro on Main  4105 Main St
#
#             city state postal_code   latitude  longitude  stars  review_count  \
# 31  Philadelphia    PA       19127  40.022466 -75.218314    3.0            41
#
#     is_open                                         attributes  \
# 31        0  {'RestaurantsReservations': 'False', 'Caters':...
#
#                          categories  \
# 31  Pizza, Restaurants, Salad, Soup
#
#                                                 hours
# 31  {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-1...
# DeSandro on Main full hours: {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-1:30', 'Thursday': '17:0-1:30', 'Friday': '17:0-0:30', 'Saturday': '17:0-0:30', 'Sunday': '17:0-21:30'}
# DeSandro on Main Friday hours: 17:0-0:30

# %% [markdown]
# #### **Business hours and Pros/Cons for "North Avenue Collective" in Chicago.**
# We chose this just because of 'Chicago' - We want to look up businesses in the city.

# %%
northAve_Collective_Est = businessData_original[(businessData_original['city'] == 'Chicago')]
display(northAve_Collective_Est)

print(f"Business found in Chicago City: {northAve_Collective_Est['name'].iloc[0]}")
northAve_Collective_Est_hoursString = northAve_Collective_Est['hours'].iloc[0]
print(f"Full hours: {northAve_Collective_Est_hoursString} \n")

attributesString = northAve_Collective_Est['attributes'].iloc[0]
attributesDict = ast.literal_eval(attributesString) if isinstance(attributesString, str) else {}
consList = []
prosList = []
for key, value in attributesDict.items():
  if key == 'BusinessParking':
    parkingDict = value if isinstance(value, dict) else ast.literal_eval(value)
    for babyKey, babyValue in parkingDict.items():
        if babyValue == 'True':
          prosList.append(babyKey)
        elif babyValue == 'False':
          consList.append(babyKey)
  else:
     if value == 'True':
          prosList.append(key)
     elif value == 'False':
          consList.append(key)

print(f'Business Pros/Advantages: {prosList}')
print(f'Business Cons/Disadvantages: {consList}')
# Out:
#        Unnamed: 0             business_id                     name  \
# 58315       58315  PbxGUBMCnQydOwAu4FAzNA  North Avenue Collective
#
#                 address     city state postal_code   latitude  longitude  \
# 58315  2511 W North Ave  Chicago    IL       62035  38.924188    -90.201
#
#        stars  review_count  is_open  \
# 58315    5.0            11        0
#
#                                               attributes  \
# 58315  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
#
#                                               categories  \
# 58315  Used, Vintage&Consignment, Shopping, HomeDecor...
#
#                                                    hours
# 58315  {'Thursday': '10:0-18:0', 'Friday': '10:0-18:0...
# Business found in Chicago City: North Avenue Collective
# Full hours: {'Thursday': '10:0-18:0', 'Friday': '10:0-18:0', 'Saturday': '10:0-18:0', 'Sunday': '12:0-16:0'}
#
# Business Pros/Advantages: ['WheelchairAccessible', 'BusinessAcceptsCreditCards', 'DogsAllowed', 'BikeParking']
# Business Cons/Disadvantages: ['ByAppointmentOnly', 'BusinessAcceptsBitcoin']

# %% [markdown]
# ### **Geo Map.**

# %%
def geoRec(query, numRec):
  '''Show recommendation as map.'''

  queryRes, city = getRec(query, numRec)
  display(queryRes)
  print('\n')
  geolocator = Nominatim(user_agent="my_geocoder")

  #Get the latitude and longitude of the city.
  cityLocation = geolocator.geocode(city, timeout=None)
  cityLatitude, cityLongitude = cityLocation.latitude, cityLocation.longitude

  #Folium map using city as the center.
  mapCenter = [cityLatitude, cityLongitude]
  mapCity = folium.Map(location=mapCenter, zoom_start=12, width=700, height=500)

  #Add a marker for the city.
  folium.Marker(location=mapCenter, popup=f"City: {city}").add_to(mapCity)

  #Map each establishment in queryRes.
  for index, row in queryRes.iterrows():
    #Use respective latitude and longitude from businesses data.
    establishmentLocation = [row['latitude'], row['longitude']]
    folium.Marker(location=establishmentLocation, popup=row['name']).add_to(mapCity)

  display(mapCity)

# %%
geoRec('Pubs in Philadelphia that are WheelchairAccessible', 5)
# Out:
# City: Philadelphia
# Services: WheelchairAccessible
# Establishment Types: ['pubs']
#        stars                       name  review_count  \
# 94471    4.5                  Bar Hygge           387
# 53651    4.5   Glory Beer Bar & Kitchen           203
# 79730    4.5  Love City Brewing Company           162
# 1106     4.5           Chase's Hop Shop           116
# 78757    4.5     Original 13 Ciderworks            65
#
#                                               categories   latitude  longitude
# 94471  Food, Restaurants, Breweries, ComfortFood, Bre...  39.967125 -75.166124
# 53651  American(New), LocalFlavor, Bars, Restaurants,...  39.948179 -75.143545
# 79730  Brewpubs, Breweries, Nightlife, Bars, Food, Ba...  39.960310 -75.155415
# 1106   ChickenWings, Nightlife, Bars, Delis, Food, Be...  40.060386 -75.084590
# 78757  American(Traditional), Food, Restaurants, Bars...  39.974598 -75.140215
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70a664839e054aaded4b5cb16afeb8c6 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70a664839e054aaded4b5cb16afeb8c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70a664839e054aaded4b5cb16afeb8c6 = L.map(
#                 &quot;map_70a664839e054aaded4b5cb16afeb8c6&quot;,
#                 {
#                     center: [39.9527237, -75.1635262],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0b9a4f90f78a53f397ff750d86f5afc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70a664839e054aaded4b5cb16afeb8c6);
#
#
#             var marker_583e571264f79a8c6782666dac83841d = L.marker(
#                 [39.9527237, -75.1635262],
#                 {}
#             ).addTo(map_70a664839e054aaded4b5cb16afeb8c6);
#
#
#         var popup_8d1c94ca9f2cb048cd1457d872232ce2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63e2949fdf4d06d64c69999d8da69e03 = $(`&lt;div id=&quot;html_63e2949fdf4d06d64c69999d8da69e03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Philadelphia&lt;/div&gt;`)[0];
#                 popup_8d1c94ca9f2cb048cd1457d872232ce2.setContent(html_63e2949fdf4d06d64c69999d8da69e03);
#
#
#
#         marker_583e571264f79a8c6782666dac83841d.bindPopup(popup_8d1c94ca9f2cb048cd1457d872232ce2)
#         ;
#
#
#
#
#             var marker_e383d72b74c7849ebb039910e51bce1e = L.marker(
#                 [39.9671254924, -75.1661240918],
#                 {}
#             ).addTo(map_70a664839e054aaded4b5cb16afeb8c6);
#
#
#         var popup_0709f261e463802d13092cceb75aa304 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acc6c647cc6c979db05f8c321570a870 = $(`&lt;div id=&quot;html_acc6c647cc6c979db05f8c321570a870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bar Hygge&lt;/div&gt;`)[0];
#                 popup_0709f261e463802d13092cceb75aa304.setContent(html_acc6c647cc6c979db05f8c321570a870);
#
#
#
#         marker_e383d72b74c7849ebb039910e51bce1e.bindPopup(popup_0709f261e463802d13092cceb75aa304)
#         ;
#
#
#
#
#             var marker_9a4bda12cf67e3c36b38ba91515b65c0 = L.marker(
#                 [39.9481792, -75.1435446],
#                 {}
#             ).addTo(map_70a664839e054aaded4b5cb16afeb8c6);
#
#
#         var popup_8adbb55753ca6673bb63580d34216822 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6509ee71e1e0e6cc847614603a4102bb = $(`&lt;div id=&quot;html_6509ee71e1e0e6cc847614603a4102bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Glory Beer Bar &amp; Kitchen&lt;/div&gt;`)[0];
#                 popup_8adbb55753ca6673bb63580d34216822.setContent(html_6509ee71e1e0e6cc847614603a4102bb);
#
#
#
#         marker_9a4bda12cf67e3c36b38ba91515b65c0.bindPopup(popup_8adbb55753ca6673bb63580d34216822)
#         ;
#
#
#
#
#             var marker_82cb4504d2a94ccdf40a2ed74ce23685 = L.marker(
#                 [39.9603099077, -75.1554151252],
#                 {}
#             ).addTo(map_70a664839e054aaded4b5cb16afeb8c6);
#
#
#         var popup_7438ee8e2596d3fe247b7a0f7e988ae2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30ae38d5e7729fa5c77645396dc43301 = $(`&lt;div id=&quot;html_30ae38d5e7729fa5c77645396dc43301&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Love City Brewing Company&lt;/div&gt;`)[0];
#                 popup_7438ee8e2596d3fe247b7a0f7e988ae2.setContent(html_30ae38d5e7729fa5c77645396dc43301);
#
#
#
#         marker_82cb4504d2a94ccdf40a2ed74ce23685.bindPopup(popup_7438ee8e2596d3fe247b7a0f7e988ae2)
#         ;
#
#
#
#
#             var marker_3c6c9cc1a60440677a2834ef44311dd3 = L.marker(
#                 [40.0603863, -75.0845897],
#                 {}
#             ).addTo(map_70a664839e054aaded4b5cb16afeb8c6);
#
#
#         var popup_50a70eba02a3395251b9bcebed276fd4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1899bdd571a6004c302ee74cd5cc030a = $(`&lt;div id=&quot;html_1899bdd571a6004c302ee74cd5cc030a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chase&#x27;s Hop Shop&lt;/div&gt;`)[0];
#                 popup_50a70eba02a3395251b9bcebed276fd4.setContent(html_1899bdd571a6004c302ee74cd5cc030a);
#
#
#
#         marker_3c6c9cc1a60440677a2834ef44311dd3.bindPopup(popup_50a70eba02a3395251b9bcebed276fd4)
#         ;
#
#
#
#
#             var marker_bd45c38d2a3ab2245d935c7fbc1afe31

# %% [markdown]
# ## **Come up with 5 queries.**

# %%
geoRec('Health&Medical in Reno that are AcceptsInsurance', 5)
# Out:
# City: Reno
# Services: AcceptsInsurance
# Establishment Types: ['health&medical']
#        stars                                  name  review_count  \
# 38349    5.0          Advanced Health Chiropractic            56
# 5071     5.0          Northern Nevada Chiropractic            49
# 9299     5.0         Peak Performance Chiropractic            44
# 96681    5.0  Alford Pediatric & General Dentistry            35
# 26034    5.0           Active Health Spine & Sport            30
#
#                                               categories   latitude  \
# 38349  PhysicalTherapy, Health&Medical, Beauty&Spas, ...  39.514546
# 5071   MassageTherapy, Chiropractors, DiagnosticImagi...  39.473220
# 9299       Chiropractors, MassageTherapy, Health&Medical  39.489066
# 96681  GeneralDentistry, Dentists, CosmeticDentists, ...  39.517828
# 26034  SportsMedicine, Health&Medical, Chiropractors,...  39.513660
#
#         longitude
# 38349 -119.859537
# 5071  -119.766852
# 9299  -119.808813
# 96681 -119.882745
# 26034 -119.807210
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0db8fe327992f6e121f3ecf994b332b {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0db8fe327992f6e121f3ecf994b332b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0db8fe327992f6e121f3ecf994b332b = L.map(
#                 &quot;map_f0db8fe327992f6e121f3ecf994b332b&quot;,
#                 {
#                     center: [39.5261206, -119.8126581],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1aefc7751263290c667728c3f2702f30 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0db8fe327992f6e121f3ecf994b332b);
#
#
#             var marker_7fc656fc2c30d5e6d94bda51736534f9 = L.marker(
#                 [39.5261206, -119.8126581],
#                 {}
#             ).addTo(map_f0db8fe327992f6e121f3ecf994b332b);
#
#
#         var popup_bbf36a5b5bb3e4734a25f8799cd6dc35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47c5bd38ff356c839b982de990bffc96 = $(`&lt;div id=&quot;html_47c5bd38ff356c839b982de990bffc96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Reno&lt;/div&gt;`)[0];
#                 popup_bbf36a5b5bb3e4734a25f8799cd6dc35.setContent(html_47c5bd38ff356c839b982de990bffc96);
#
#
#
#         marker_7fc656fc2c30d5e6d94bda51736534f9.bindPopup(popup_bbf36a5b5bb3e4734a25f8799cd6dc35)
#         ;
#
#
#
#
#             var marker_43469659273f8247ddcf46f05f03f07d = L.marker(
#                 [39.514546, -119.859537],
#                 {}
#             ).addTo(map_f0db8fe327992f6e121f3ecf994b332b);
#
#
#         var popup_bcf987e243d6f5094679b50ca81b3410 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecb46a72364ead4981c4ae1b5e302312 = $(`&lt;div id=&quot;html_ecb46a72364ead4981c4ae1b5e302312&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Advanced Health Chiropractic&lt;/div&gt;`)[0];
#                 popup_bcf987e243d6f5094679b50ca81b3410.setContent(html_ecb46a72364ead4981c4ae1b5e302312);
#
#
#
#         marker_43469659273f8247ddcf46f05f03f07d.bindPopup(popup_bcf987e243d6f5094679b50ca81b3410)
#         ;
#
#
#
#
#             var marker_5b6fb2f912afedc5bcabf5ad8e8fef9b = L.marker(
#                 [39.4732197, -119.766852],
#                 {}
#             ).addTo(map_f0db8fe327992f6e121f3ecf994b332b);
#
#
#         var popup_c10c3267e038452f090ac6feb2b5ae80 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7775314a53b8914a1d1705f7acbcadbd = $(`&lt;div id=&quot;html_7775314a53b8914a1d1705f7acbcadbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Northern Nevada Chiropractic&lt;/div&gt;`)[0];
#                 popup_c10c3267e038452f090ac6feb2b5ae80.setContent(html_7775314a53b8914a1d1705f7acbcadbd);
#
#
#
#         marker_5b6fb2f912afedc5bcabf5ad8e8fef9b.bindPopup(popup_c10c3267e038452f090ac6feb2b5ae80)
#         ;
#
#
#
#
#             var marker_0115e7ca3b3365ee9d32da35f797691d = L.marker(
#                 [39.489065869, -119.8088134652],
#                 {}
#             ).addTo(map_f0db8fe327992f6e121f3ecf994b332b);
#
#
#         var popup_f9fc8c4919d400faadc050a0e39f79d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_352f91b1755bb141c8e3907a2f176154 = $(`&lt;div id=&quot;html_352f91b1755bb141c8e3907a2f176154&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Peak Performance Chiropractic&lt;/div&gt;`)[0];
#                 popup_f9fc8c4919d400faadc050a0e39f79d2.setContent(html_352f91b1755bb141c8e3907a2f176154);
#
#
#
#         marker_0115e7ca3b3365ee9d32da35f797691d.bindPopup(popup_f9fc8c4919d400faadc050a0e39f79d2)
#         ;
#
#
#
#
#             var marker_8d97de9a544efa32b16afa08867b2faf = L.marker(
#                 [39.5178277, -119.8827455],
#                 {}
#             ).addTo(map_f0db8fe327992f6e121f3ecf994b332b);
#
#
#         var popup_cb6e492d4980ffa8eafd2004dd218b01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7889de64edb47aabcb18562835a81d0e = $(`&lt;div id=&quot;html_7889de64edb47aabcb18562835a81d0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alford Pediatric &amp; General Dentistry&lt;/div&gt;`)[0];
#                 popup_cb6e492d4980ffa8eafd2004dd218b01.setContent(html_7889de64edb47aabcb18562835a81d0e);
#
#
#
#         marker_8d97de9a544efa32b16afa08867b2faf.bindPopup(popup_cb6e492d4980ffa8eafd2004dd218b01)
#         ;
#
#
#
#
#             var marker_4bd

# %%
geoRec('Best Beauty&Spas in Nashville that are BusinessAcceptsCreditCards', 5)
# Out:
# City: Nashville
# Services: BusinessAcceptsCreditCards
# Establishment Types: ['beauty&spas']
#        stars                            name  review_count  \
# 33028    5.0              Spa Haus Nashville           161
# 28969    5.0                East Nails & Spa            90
# 99996    5.0        61Five Health & Wellness            78
# 27761    5.0  Bucca Reflexology And Foot Spa            76
# 95022    5.0              The Wax Pot Studio            65
#
#                                               categories   latitude  longitude
# 33028  Cosmetics&BeautySupply, Reiki, SkinCare, Eyela...  36.115331 -86.765821
# 28969  Beauty&Spas, NailSalons, SkinCare, HairRemoval...  36.182924 -86.749573
# 99996  IVHydration, Beauty&Spas, MedicalCenters, Nutr...  36.153587 -86.799671
# 27761  Beauty&Spas, Reflexology, Massage, Health&Medical  36.127826 -86.842759
# 95022  Massage, EyelashService, Beauty&Spas, HairRemo...  36.144598 -86.795255
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5843c827df61bc62e1c546be2c4ad950 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5843c827df61bc62e1c546be2c4ad950&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5843c827df61bc62e1c546be2c4ad950 = L.map(
#                 &quot;map_5843c827df61bc62e1c546be2c4ad950&quot;,
#                 {
#                     center: [36.1622767, -86.7742984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e925b7ceabf11667dca1e866f4591ef6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5843c827df61bc62e1c546be2c4ad950);
#
#
#             var marker_623847af5c99a245aee8c7f3a016353a = L.marker(
#                 [36.1622767, -86.7742984],
#                 {}
#             ).addTo(map_5843c827df61bc62e1c546be2c4ad950);
#
#
#         var popup_8dba4ad5538dfad19060a2c3b919572b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ca4bf1d88ffbda346d12b7118b91b02 = $(`&lt;div id=&quot;html_9ca4bf1d88ffbda346d12b7118b91b02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Nashville&lt;/div&gt;`)[0];
#                 popup_8dba4ad5538dfad19060a2c3b919572b.setContent(html_9ca4bf1d88ffbda346d12b7118b91b02);
#
#
#
#         marker_623847af5c99a245aee8c7f3a016353a.bindPopup(popup_8dba4ad5538dfad19060a2c3b919572b)
#         ;
#
#
#
#
#             var marker_33cc09cae852eec65e2506d753984da7 = L.marker(
#                 [36.115331, -86.765821],
#                 {}
#             ).addTo(map_5843c827df61bc62e1c546be2c4ad950);
#
#
#         var popup_7f1896c5f5f269966baf667ada577c54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d5ce4c0a5d65d487459fbb8cd4562a0 = $(`&lt;div id=&quot;html_9d5ce4c0a5d65d487459fbb8cd4562a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Spa Haus Nashville&lt;/div&gt;`)[0];
#                 popup_7f1896c5f5f269966baf667ada577c54.setContent(html_9d5ce4c0a5d65d487459fbb8cd4562a0);
#
#
#
#         marker_33cc09cae852eec65e2506d753984da7.bindPopup(popup_7f1896c5f5f269966baf667ada577c54)
#         ;
#
#
#
#
#             var marker_2f0348319f28c5c603d91f73ab8168ed = L.marker(
#                 [36.1829242, -86.749573],
#                 {}
#             ).addTo(map_5843c827df61bc62e1c546be2c4ad950);
#
#
#         var popup_8218035e619528307fba5bad291abb42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ecfacd20c4023c77376010e85359a95 = $(`&lt;div id=&quot;html_4ecfacd20c4023c77376010e85359a95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;East Nails &amp; Spa&lt;/div&gt;`)[0];
#                 popup_8218035e619528307fba5bad291abb42.setContent(html_4ecfacd20c4023c77376010e85359a95);
#
#
#
#         marker_2f0348319f28c5c603d91f73ab8168ed.bindPopup(popup_8218035e619528307fba5bad291abb42)
#         ;
#
#
#
#
#             var marker_a74fb8d35538276c1cf640922990bba4 = L.marker(
#                 [36.1535874, -86.7996714],
#                 {}
#             ).addTo(map_5843c827df61bc62e1c546be2c4ad950);
#
#
#         var popup_03d9f58d9a83a2a233ebee92678a037b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3775a2755e52bc5f02598c923c54ca9 = $(`&lt;div id=&quot;html_e3775a2755e52bc5f02598c923c54ca9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;61Five Health &amp; Wellness&lt;/div&gt;`)[0];
#                 popup_03d9f58d9a83a2a233ebee92678a037b.setContent(html_e3775a2755e52bc5f02598c923c54ca9);
#
#
#
#         marker_a74fb8d35538276c1cf640922990bba4.bindPopup(popup_03d9f58d9a83a2a233ebee92678a037b)
#         ;
#
#
#
#
#             var marker_de8abbe8d69f8afa77da9d23293cc06f = L.marker(
#                 [36.1278262, -86.8427594],
#                 {}
#             ).addTo(map_5843c827df61bc62e1c546be2c4ad950);
#
#
#         var popup_b15d164438ab961edc6b86ebe394db47 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef16d3d434c09cc351c629c489e3593b = $(`&lt;div id=&quot;html_ef16d3d434c09cc351c629c489e3593b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bucca Reflexology And Foot Spa&lt;/div&gt;`)[0];
#                 popup_b15d164438ab961edc6b86ebe394db47.setContent(html_ef16d3d434c09cc351c629c489e3593b);
#
#
#
#         marker_de8abbe8d69f8afa77da9d23293cc06f.bindPopup(popup_b15d164438ab961edc6b86ebe394db47)
#         ;
#
#
#
#
#             var marker_90cdce8d2a30abe5d4277dfde95c8a12 = L.m

# %%
geoRec('FastFood Restaurants in Ashland City', 5)
# Out:
# City: Ashland City
# Establishment Types: ['fastfood', 'restaurants']
#        stars            name  review_count  \
# 43975    2.0      McDonald's            14
# 5        2.0  Sonic Drive-In             6
# 67798    1.5             KFC             6
# 64266    1.0     Burger King             9
#
#                                               categories   latitude  longitude
# 43975   Restaurants, FastFood, Burgers, Coffee&Tea, Food  36.273119 -87.062329
# 5      Burgers, FastFood, Sandwiches, Food, IceCream&...  36.269593 -87.058943
# 67798   Restaurants, ChickenWings, FastFood, ChickenShop  36.270909 -87.059858
# 64266                     Restaurants, FastFood, Burgers  36.249847 -87.033478
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b258caab37478dfe12cfb5926abb2aaf {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b258caab37478dfe12cfb5926abb2aaf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b258caab37478dfe12cfb5926abb2aaf = L.map(
#                 &quot;map_b258caab37478dfe12cfb5926abb2aaf&quot;,
#                 {
#                     center: [36.2742207, -87.0641699],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38610fce8dac79f807973700508dce85 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b258caab37478dfe12cfb5926abb2aaf);
#
#
#             var marker_4dd6a6d9d7fab599459e6e0e3abf3030 = L.marker(
#                 [36.2742207, -87.0641699],
#                 {}
#             ).addTo(map_b258caab37478dfe12cfb5926abb2aaf);
#
#
#         var popup_b35ed3fa59975f12c0a76cc1ac27bb2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b316901ea389bfc8bc8745976b55ad4c = $(`&lt;div id=&quot;html_b316901ea389bfc8bc8745976b55ad4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Ashland City&lt;/div&gt;`)[0];
#                 popup_b35ed3fa59975f12c0a76cc1ac27bb2b.setContent(html_b316901ea389bfc8bc8745976b55ad4c);
#
#
#
#         marker_4dd6a6d9d7fab599459e6e0e3abf3030.bindPopup(popup_b35ed3fa59975f12c0a76cc1ac27bb2b)
#         ;
#
#
#
#
#             var marker_54800312c1e93ae9b67185e6606c58a4 = L.marker(
#                 [36.2731194, -87.0623285],
#                 {}
#             ).addTo(map_b258caab37478dfe12cfb5926abb2aaf);
#
#
#         var popup_c6c1c591630f9c59ebc594577e99b281 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf854d546f77ae6e8d0fe84e4acd45e4 = $(`&lt;div id=&quot;html_cf854d546f77ae6e8d0fe84e4acd45e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;McDonald&#x27;s&lt;/div&gt;`)[0];
#                 popup_c6c1c591630f9c59ebc594577e99b281.setContent(html_cf854d546f77ae6e8d0fe84e4acd45e4);
#
#
#
#         marker_54800312c1e93ae9b67185e6606c58a4.bindPopup(popup_c6c1c591630f9c59ebc594577e99b281)
#         ;
#
#
#
#
#             var marker_3468f9ba1c9523890009c54c5f422249 = L.marker(
#                 [36.269593, -87.058943],
#                 {}
#             ).addTo(map_b258caab37478dfe12cfb5926abb2aaf);
#
#
#         var popup_956cf8e99d843b9dff030db7ccc4dfbf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cceef510c3d4b3beb34f0839c21054c8 = $(`&lt;div id=&quot;html_cceef510c3d4b3beb34f0839c21054c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sonic Drive-In&lt;/div&gt;`)[0];
#                 popup_956cf8e99d843b9dff030db7ccc4dfbf.setContent(html_cceef510c3d4b3beb34f0839c21054c8);
#
#
#
#         marker_3468f9ba1c9523890009c54c5f422249.bindPopup(popup_956cf8e99d843b9dff030db7ccc4dfbf)
#         ;
#
#
#
#
#             var marker_f8b7997ddd0cc072914ca9605f63ae3d = L.marker(
#                 [36.2709085171, -87.05985763],
#                 {}
#             ).addTo(map_b258caab37478dfe12cfb5926abb2aaf);
#
#
#         var popup_da628c10cc26bb181dbdb704fcf66a71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a8d29eaf0f0e2ab99519f04293e33dd = $(`&lt;div id=&quot;html_2a8d29eaf0f0e2ab99519f04293e33dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KFC&lt;/div&gt;`)[0];
#                 popup_da628c10cc26bb181dbdb704fcf66a71.setContent(html_2a8d29eaf0f0e2ab99519f04293e33dd);
#
#
#
#         marker_f8b7997ddd0cc072914ca9605f63ae3d.bindPopup(popup_da628c10cc26bb181dbdb704fcf66a71)
#         ;
#
#
#
#
#             var marker_d19c9f3423556e6706a852fb5016b342 = L.marker(
#                 [36.2498474024, -87.0334777022],
#                 {}
#             ).addTo(map_b258caab37478dfe12cfb5926abb2aaf);
#
#
#         var popup_6e0053e977e3f74b8d49af924c12b976 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cd64a5abf84b68350f3f8c718022d30 = $(`&lt;div id=&quot;html_1cd64a5abf84b68350f3f8c718022d30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Burger King&lt;/div&gt;`)[0];
#                 popup_6e0053e977e3f74b8d49af924c12b976.setContent(html_1cd64a5abf84b68350f3f8c718022d30);
#
#
#
#         marker_d19c9f3423556e6706a852fb5016b342.bindPopup(popup_6e0053e977e3f74b8d49af924c12b976)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !

# %%
#This query will return empty since there is no fastfood restaurants in Ashland City with stars >= 4.0.
geoRec('Best FastFood Restaurants in Ashland City', 5)
# Out:
# City: Ashland City
# Establishment Types: ['fastfood', 'restaurants']
# Empty DataFrame
# Columns: [stars, name, review_count, categories, latitude, longitude]
# Index: []
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e59bc964e1dd521225914ae601974b7 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e59bc964e1dd521225914ae601974b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e59bc964e1dd521225914ae601974b7 = L.map(
#                 &quot;map_3e59bc964e1dd521225914ae601974b7&quot;,
#                 {
#                     center: [36.2742207, -87.0641699],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4165ed389392287b685a06e9b6b51d9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3e59bc964e1dd521225914ae601974b7);
#
#
#             var marker_d7c99f73d0a3f48c2ca6a128b5b2040a = L.marker(
#                 [36.2742207, -87.0641699],
#                 {}
#             ).addTo(map_3e59bc964e1dd521225914ae601974b7);
#
#
#         var popup_99533f2d8c0d90c0369e5c3a354786f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4cd32dce489cad8801f96cae6a9f9bf2 = $(`&lt;div id=&quot;html_4cd32dce489cad8801f96cae6a9f9bf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Ashland City&lt;/div&gt;`)[0];
#                 popup_99533f2d8c0d90c0369e5c3a354786f3.setContent(html_4cd32dce489cad8801f96cae6a9f9bf2);
#
#
#
#         marker_d7c99f73d0a3f48c2ca6a128b5b2040a.bindPopup(popup_99533f2d8c0d90c0369e5c3a354786f3)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geoRec('Italian Restaurants in Affton that do Caters', 5)
# Out:
# City: Affton
# Services: Caters
# Establishment Types: ['italian', 'restaurants']
#        stars                             name  review_count  \
# 8        3.0            Tsevi's Pub And Grill            19
# 30500    2.5  Olive Garden Italian Restaurant            87
#
#                                               categories   latitude  longitude
# 8      Pubs, Restaurants, Italian, Bars, American(Tra...  38.565165 -90.321087
# 30500  Bars, Restaurants, WineBars, Nightlife, Soup, ...  38.523708 -90.356832
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1dfbe9a55556c9d1b0f97b5b46d1f4bf {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1dfbe9a55556c9d1b0f97b5b46d1f4bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1dfbe9a55556c9d1b0f97b5b46d1f4bf = L.map(
#                 &quot;map_1dfbe9a55556c9d1b0f97b5b46d1f4bf&quot;,
#                 {
#                     center: [38.5521715, -90.3263911],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96f8a7aaa83c9c87c64ece9565adf99a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1dfbe9a55556c9d1b0f97b5b46d1f4bf);
#
#
#             var marker_645211d10f4fe93360ac2c0873399701 = L.marker(
#                 [38.5521715, -90.3263911],
#                 {}
#             ).addTo(map_1dfbe9a55556c9d1b0f97b5b46d1f4bf);
#
#
#         var popup_238e018e8d70e82f70ff054cd2edf187 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b23fb788b2aaf07f54c1569c072e2b20 = $(`&lt;div id=&quot;html_b23fb788b2aaf07f54c1569c072e2b20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Affton&lt;/div&gt;`)[0];
#                 popup_238e018e8d70e82f70ff054cd2edf187.setContent(html_b23fb788b2aaf07f54c1569c072e2b20);
#
#
#
#         marker_645211d10f4fe93360ac2c0873399701.bindPopup(popup_238e018e8d70e82f70ff054cd2edf187)
#         ;
#
#
#
#
#             var marker_90c93260417359f7a356981ed0efd743 = L.marker(
#                 [38.5651648, -90.3210868],
#                 {}
#             ).addTo(map_1dfbe9a55556c9d1b0f97b5b46d1f4bf);
#
#
#         var popup_6a7636b34bd14fc01bb25a2dda690606 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8fcfa69e2ff06be00c79a728ec53a69 = $(`&lt;div id=&quot;html_c8fcfa69e2ff06be00c79a728ec53a69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tsevi&#x27;s Pub And Grill&lt;/div&gt;`)[0];
#                 popup_6a7636b34bd14fc01bb25a2dda690606.setContent(html_c8fcfa69e2ff06be00c79a728ec53a69);
#
#
#
#         marker_90c93260417359f7a356981ed0efd743.bindPopup(popup_6a7636b34bd14fc01bb25a2dda690606)
#         ;
#
#
#
#
#             var marker_f7856e8852d9ddb17c768407ab13a8ef = L.marker(
#                 [38.5237080906, -90.3568317377],
#                 {}
#             ).addTo(map_1dfbe9a55556c9d1b0f97b5b46d1f4bf);
#
#
#         var popup_042fab2ac1c9b0d0c29d4c2d3aa45082 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b98a3e63f2b452e60275c4925b90166 = $(`&lt;div id=&quot;html_3b98a3e63f2b452e60275c4925b90166&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Olive Garden Italian Restaurant&lt;/div&gt;`)[0];
#                 popup_042fab2ac1c9b0d0c29d4c2d3aa45082.setContent(html_3b98a3e63f2b452e60275c4925b90166);
#
#
#
#         marker_f7856e8852d9ddb17c768407ab13a8ef.bindPopup(popup_042fab2ac1c9b0d0c29d4c2d3aa45082)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !jupyter nbconvert --to html CSS575-Final-Project-Task1.ipynb
# Out:
# [NbConvertApp] Converting notebook CSS575-Final-Project-Task1.ipynb to html
# [NbConvertApp] Writing 833409 bytes to CSS575-Final-Project-Task1.html
