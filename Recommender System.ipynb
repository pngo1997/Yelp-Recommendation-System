# %% [markdown]
# ## **Task 2: Recommender System using Embeddings.**
# ### **Step 1: Create Embeddings.**

# %%
#Mount my Google Drive
from google.colab import drive
drive.mount("/content/drive")
import os
directory = '/content/drive/My Drive/CSC575 Final Project'
os.chdir(directory)

#Ensure the files are there (in the folder)
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/CSC575 Final Project

# %% [markdown]
# ### **Loading Datasets**.

# %%
#Importing Necessary Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#Text preprocessing.
import re
import ast
import nltk
from nltk.corpus import stopwords
import spacy
from spacy.tokens import Span
#Cosine calculation.
from numpy.linalg import norm
nlp = spacy.load("en_core_web_sm")
#Warnings.
import warnings
warnings.filterwarnings("ignore")
#Geo location.
import folium
from geopy.geocoders import Nominatim

# %% [markdown]
# **Loading Datasets**

# %%
#Training data.
df_train = pd.read_csv("reviews_train.csv", sep='\t', encoding = 'ISO-8859-1')

# %%
df_train.head(3)
# Out:
#                 review_id                 user_id             business_id  \
# 0  A-8BBGnBoz5-K1WaM5Cgaw  DUxCdkXnwYEzHZvT8MyvIw  ju4YP8SLdR_BmWr_-Xh83Q
# 1  k--beJRNBZzFklRoppa2MA  SAgf1IxxuomOWSIDzy07pQ  uE40984_YDgVvPeRpFcCaQ
# 2  qmr304jvtYetK5i_Djrx_A  cMkPQZVDOibs2bz8St7Acg  JvawJ9bSr22xn4R9oLvl_w
#
#    stars  useful  funny  cool  \
# 0      5       2      0     1
# 1      5       0      0     0
# 2      3       0      0     0
#
#                                                 text                 date
# 0  Best pho in Santa Barbara County.  Staff are g...  2018-07-27 00:09:23
# 1  We came for the hot chicken but were won over ...  2014-02-26 13:05:47
# 2  I really should have used my better judgement ...  2014-02-26 22:33:39

# %%
#Test data.
df_test = pd.read_csv("reviews_test_all.csv", sep='\t', encoding = 'ISO-8859-1')

# %%
df_test.head(3)
# Out:
#    Unnamed: 0               review_id                 user_id  \
# 0       37039  8QSAs3yVhcNS0y1fWSn41Q  BY_7xEliSP5iEig9bemaKw
# 1       19778  -lNpxdJNrvMtZ_RTvT2NtA  djOl6zKvKdbt4lNnDKUXJg
# 2       80124  7Ylcy1txacpnY76275KqQw  1iokf9rM43YAwxsa8bp1OQ
#
#               business_id  stars  useful  funny  cool  \
# 0  e86IBzGCsrnhJbD_wELj7w      3       1      0     0
# 1  z22hSRptt_DS0nWjsIka2A      5       0      0     0
# 2  jRLskcm_icZIKs81mYC4iQ      4       5      3     3
#
#                                                 text                 date
# 0  The main course was actually very tasty and th...  2011-01-16 20:23:33
# 1  Outback is my favorite steakhouse. I've dined ...  2015-05-13 17:03:27
# 2  I absolutely love Ethiopian, I'd eat it every ...  2015-04-22 17:26:46

# %%
#Businesses data.
df_businesses = pd.read_csv("businesses.csv", sep='\t', encoding = 'ISO-8859-1')

# %%
df_businesses.head(3)
# Out:
#    Unnamed: 0             business_id                      name  \
# 0           0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1           1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2           2  tUFrWirKiKi_TAnsVWINQQ                    Target
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
#
#                                                hours
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...

# %% [markdown]
# ### **Text Preprocessing.**
# **Tokenize.**

# %%
def process_text(text):
  '''Tokenize_text function using Spacy's default stop words.'''

  #Lowering all text.
  text = re.sub(r'[^\w\s]', '', text.lower())

  #Filter out tokens.
  filtered_tokens = []

  for token_text in nlp(text):
    #Get tokens that are alpha, and not stop words.
    if token_text.text.isalpha() and token_text.text not in nlp.Defaults.stop_words:
      #Token length has to be more than 2 and less than 19.
      if 2 < len(token_text) < 19:
        filtered_tokens.append(str(token_text))
  return filtered_tokens

# %%
#--Takes a long time to process text: 40 mins!--
#Apply the tokenization function to all 'text' in the review training dataset.
processed_text = df_train.text.apply(process_text)

# %%
processed_text.head(5)
# Out:
# 0    [best, pho, santa, barbara, county, staff, gre...
# 1    [came, hot, chicken, won, entire, menu, ill, s...
# 2    [better, judgement, ruled, eating, joint, bour...
# 3    [place, relatively, smaller, pho, places, sant...
# 4    [best, southeast, restaurant, philadelphia, fo...
# Name: text, dtype: object

# %%
#Convert into a list of tokenized strings.
clean_txt = [str(i) for i in processed_text]

#Copied data frame with cleaned text.
cln_train = df_train
cln_train["cleaned_text"] = clean_txt
cln_train.head(5)
# Out:
#                 review_id                 user_id             business_id  \
# 0  A-8BBGnBoz5-K1WaM5Cgaw  DUxCdkXnwYEzHZvT8MyvIw  ju4YP8SLdR_BmWr_-Xh83Q
# 1  k--beJRNBZzFklRoppa2MA  SAgf1IxxuomOWSIDzy07pQ  uE40984_YDgVvPeRpFcCaQ
# 2  qmr304jvtYetK5i_Djrx_A  cMkPQZVDOibs2bz8St7Acg  JvawJ9bSr22xn4R9oLvl_w
# 3  KXNdht_of5t-Dh1eoaeYHQ  9m13F_RCcz_r48tQH82I5A  bdfZdB2MTXlT6-RBjSIpQg
# 4  asJ8k1sm8jO01bi-s5JW8g  goySBsZ3QJfSaElPIDIzLw  14ZGwnDyydXdSBsLXpSUrA
#
#    stars  useful  funny  cool  \
# 0      5       2      0     1
# 1      5       0      0     0
# 2      3       0      0     0
# 3      3       0      0     0
# 4      5       0      0     0
#
#                                                 text                 date  \
# 0  Best pho in Santa Barbara County.  Staff are g...  2018-07-27 00:09:23
# 1  We came for the hot chicken but were won over ...  2014-02-26 13:05:47
# 2  I really should have used my better judgement ...  2014-02-26 22:33:39
# 3  This place is relatively smaller than other ph...  2013-12-09 08:12:28
# 4  Best Southeast restaurant in Philadelphia. The...  2011-06-03 03:54:54
#
#                                         cleaned_text
# 0  ['best', 'pho', 'santa', 'barbara', 'county', ...
# 1  ['came', 'hot', 'chicken', 'won', 'entire', 'm...
# 2  ['better', 'judgement', 'ruled', 'eating', 'jo...
# 3  ['place', 'relatively', 'smaller', 'pho', 'pla...
# 4  ['best', 'southeast', 'restaurant', 'philadelp...

# %% [markdown]
# **Applied for user_id data.**

# %%
#Create USER dataframe.
user_train = cln_train.groupby("user_id")["cleaned_text"].agg(list).reset_index()
user_train["cleaned_text"] = user_train["cleaned_text"].apply(lambda x: " ".join(map(str, x)))
user_train.head(5)
# Out:
#                   user_id                                       cleaned_text
# 0  ---2PmXbF47D870stH1jqA  ['matter', 'night', 'goservice', 'food', 'exce...
# 1  --4AjktZiHowEIBCMd4CZA  ['love', 'village', 'whiskey', 'shame', 'crowd...
# 2  --E0uVPphTORm_OiZ5KCvA  ['worth', 'wait', 'worked', 'restaurants', 'to...
# 3  --KMTwCrhKKUmr7riuS4WQ  ['loved', 'place', 'food', 'atmosphere', 'sant...
# 4  --S8M395r8NtOCvS2LRfDw  ['awesome', 'pizza', 'large', 'piewingsand', '...

# %% [markdown]
# **Applied for business_id data.**

# %%
#Create BUSINESS dataframe.
business_train = cln_train.groupby("business_id")["cleaned_text"].agg(list).reset_index()
business_train["cleaned_text"] = business_train["cleaned_text"].apply(lambda x: "".join(map(str, x)))
business_train.head(5)
# Out:
#               business_id                                       cleaned_text
# 0  --ZVrH2X2QXBFdCilbirsw  ['best', 'hoagies', 'prosciutto', 'classic', '...
# 1  --_9CAxgfXZmoFdNIRrhHA  ['huge', 'place', 'boxes', 'big', 'store', 're...
# 2  -02xFuruu85XmDn2xiynJw  ['new', 'tucson', 'new', 'physician', 'recomme...
# 3  -0Ym1Wg3bXd_TDz8JtvOQg  ['neat', 'trendy', 'little', 'ice', 'cream', '...
# 4  -0fvhILrC9UsQ6gLNpZlTQ  ['try', 'omg', 'stopped', 'night', 'sampling',...

# %% [markdown]
# ### **Create Embeddings.**

# %%
def load_glove(vector_len=50):
  '''Function using Glove.'''

  #Vector_len must be 50/100/200/300.
  GloVe = f"glove.6B.{vector_len}d.txt"

  #Dictionary stores embeddings of all words.
  embeddings_dict = {}

  with open(GloVe, 'r', encoding="utf-8") as f:
    for line in f:
      values = line.split()
      word = str(values[0])

      vector = np.asarray(values[1:], "float32")
      embeddings_dict[word] = vector
  return embeddings_dict

#Using vector length = 50 per recommendation.
glove_embeddings = load_glove(50)

# %%
def compute_mean_embedding(words, embeddings_dict):
  '''Function to compute mean embedding of a list of words.'''

  #Filter embedding_dict by words and store the embeddings in a list.
  embeddings = [embeddings_dict[word] for word in words if word in embeddings_dict]

  #Check if any embeddings were found.
  if embeddings:
    #Calculate the mean of the embeddings and return the result.
    return np.mean(embeddings, axis=0)
  else:
    #Return a zero vector if no embeddings were found.
    return np.zeros(len(next(iter(embeddings_dict.values()))))

# %% [markdown]
# **Generate mean embeddings.**

# %%
#Update the user dataframe with mean embeddings.
user_train['mean_embedding'] = user_train['cleaned_text'].apply(lambda x: compute_mean_embedding(x, glove_embeddings))

#Update the business dataframe with mean embeddings.
business_train['mean_embedding'] = business_train['cleaned_text'].apply(lambda x: compute_mean_embedding(x, glove_embeddings))

# %%
#Drop the cleaned text column.
user_train.drop("cleaned_text", axis=1, inplace=True)
business_train.drop("cleaned_text", axis=1, inplace=True)

# %%
#Check if the length of value is greater than or smaller than 50.
busineslen = business_train["mean_embedding"].apply(lambda x: len(x) == 50).any()

#Check if there are any issues while calculating mean.
print(f"Are the length of embedding equal to 50: {busineslen}")

#Check if the length equals to 50.
userlen = user_train["mean_embedding"].apply(lambda x: len(x) == 50).any()

#Check if there are any issues while calculating mean.
print(f"Are the length of embedding equal to 50: {userlen}")
# Out:
# Are the length of embedding equal to 50: True
# Are the length of embedding equal to 50: True

# %%
#User data.
user_train.head(5)
# Out:
#                   user_id                                     mean_embedding
# 0  ---2PmXbF47D870stH1jqA  [-0.040199738, 0.86262065, 0.5210789, 0.398323...
# 1  --4AjktZiHowEIBCMd4CZA  [-0.04254708, 0.8526091, 0.5595566, 0.43888918...
# 2  --E0uVPphTORm_OiZ5KCvA  [-0.048984144, 0.83067375, 0.5336113, 0.415816...
# 3  --KMTwCrhKKUmr7riuS4WQ  [-0.051070765, 0.83776945, 0.5122076, 0.394447...
# 4  --S8M395r8NtOCvS2LRfDw  [-0.013747137, 0.8503984, 0.5158654, 0.3981377...

# %%
#Busines data.
business_train.head(5)
# Out:
#               business_id                                     mean_embedding
# 0  --ZVrH2X2QXBFdCilbirsw  [-0.054003138, 0.8348256, 0.48453295, 0.372190...
# 1  --_9CAxgfXZmoFdNIRrhHA  [-0.061999418, 0.85494626, 0.5135551, 0.397855...
# 2  -02xFuruu85XmDn2xiynJw  [-0.06751067, 0.84385616, 0.5371855, 0.4114175...
# 3  -0Ym1Wg3bXd_TDz8JtvOQg  [-0.0600089, 0.854752, 0.5121427, 0.39534807, ...
# 4  -0fvhILrC9UsQ6gLNpZlTQ  [-0.06821111, 0.8545435, 0.50191456, 0.3986616...

# %% [markdown]
# ### **Step 2: Recommendations (Rating Predictions).**

# %% [markdown]
# **Note:** Since there are either business/user IDs value exists in test data, but not in the train data. We agreed to pass on that pairs.
#
# It does not make sense to do data imputation here, since it represents a user-business's unique relationship characteristics.
#
# **There are 5,520 pairs of business/user IDs that satisfies.**

# %%
def compute_predicted_score(user_id, business_id=None, user_train = user_train, business_train = business_train):
  '''Function to compute the predicted score.'''

  #Get user ID.
  user = user_train[user_train["user_id"] == user_id]
  #Get business_id.
  business = business_train[business_train["business_id"] == business_id]

  #If both id's exists in training data then.
  if len(user) != 0 and len(business) !=0:
    #Get the embedding for user.
    user_embedding = user["mean_embedding"].values[0]
    #Get the embedding for business.
    business_embedding = business["mean_embedding"].values[0]
    #Get the dot product of the embeddings.
    dot_product = np.dot(user_embedding, business_embedding)
    return dot_product

  #Either one of the ids is not in the training data, so we pass None.
  else:
    return None

# %%
def compute_squared_error(prediction, ground_truth):
  '''Computing squared error.'''
  return (prediction - ground_truth) ** 2

# %%
def compute_rmse(predictions):
  '''Computing RMSE.'''

  #Get root mean squared error.
  mse = np.mean(predictions)
  return np.sqrt(mse)

# %% [markdown]
# **Make prediction on test data.**

# %%
#--Takes 3 mins to run the cell!--
#Lists to store prediction (dot product), and the ground true (stars) values.
prediction = []
ground_truths = []

#Iterate through test data frame.
for idx, row in df_test.iterrows():

  #Get user/business IDs
  user_id = row["user_id"]
  business_id = row["business_id"]

  #Compute the score for each case.
  predicted = compute_predicted_score(user_id, business_id)

  #If predicted is calculable / not None.
  if predicted is not None:
    #Get the true value for that row.
    y_true = row["stars"]

    #Append the predicted value.
    prediction.append(predicted)
    #Append the true value.
    ground_truths.append(y_true)

# %%
print('Prediction (dot product value) for first 5 pairs:')
prediction[:5]
# Out:
# Prediction (dot product value) for first 5 pairs:
# [15.320987, 15.26693, 15.388164, 15.225558, 15.357195]

# %%
print('Ground truth (stars value) for first 5 pairs:')
ground_truths[:5]
# Out:
# Ground truth (stars value) for first 5 pairs:
# [3, 4, 4, 3, 5]

# %% [markdown]
# **Note:** At this point we unsure to use either:
#
# 1. The original dot product value to calculate RMSE.
# 2. Create a 'prediction' stars system based on dot product values to calculate RMSE.
#
# Ultimately, we decided to do both approaches.

# %% [markdown]
# **Create stars system prediction based on dot product values.**

# %%
#Defining range of dot product values and star ratings.
min_dot_prod = min(prediction)
max_dot_prod = max(prediction)
star_rating = np.arange(1,6)

#Define the num of bins.
num_bin = len(star_rating) - 1

#Generating 5 evenly-spaced bin boundaries between min and max dot product values.
bin_boundaries = np.linspace(min_dot_prod, max_dot_prod, num_bin+1)

# %%
def assign_start_rating(dot_product):
  '''Function to assign dot product values to start rating.'''

  #Value is considered to be in the bin if <= the right boundary.
  return np.digitize(dot_product, bin_boundaries, right=True) - 1

# %%
#Binning the predictions.
binned_predictions = [assign_start_rating(pred) for pred in prediction]

# %%
print('Prediction (stars value) for first 5 pairs:')
binned_predictions[:5]
# Out:
# Prediction (stars value) for first 5 pairs:
# [3, 3, 3, 2, 3]

# %% [markdown]
# **Calculate Squared-error.**

# %%
#Binned data.
squared_error_binned = []

#Iterating through the binned predictions and get the squared error.
for i in range(len(binned_predictions)):
  squared_error_binned.append(compute_squared_error(binned_predictions[i], ground_truths[i]))


#Unbinned data.
squared_error_unbinned = []

#Iterating through the binned predictions and get the squared error.
for i in range(len(prediction)):
  squared_error_unbinned.append(compute_squared_error(prediction[i], ground_truths[i]))

# %%
print('Squared error for first 5 pairs - binned:')
squared_error_binned[:5]
# Out:
# Squared error for first 5 pairs - binned:
# [0, 1, 1, 1, 4]

# %%
print('Squared error for first 5 pairs - unbinned:')
squared_error_unbinned[:5]
# Out:
# Squared error for first 5 pairs - unbinned:
# [151.80671443802657,
#  126.94370320771122,
#  129.6902694193932,
#  149.46427528077857,
#  107.27148620720618]

# %%
#Compute and print RMSE for binned predictions.
print(f"RMSE with binning predictions: {compute_rmse(squared_error_binned):.2f}")

#Compute the rmse score without binned predictions.
print(f"RMSE without binning predictions: {compute_rmse(squared_error_unbinned):.2f}")
# Out:
# RMSE with binning predictions: 1.89
# RMSE without binning predictions: 11.45

# %% [markdown]
# ## **Task 3: Item-based Collaborative Recommendation using Embeddings.**

# %% [markdown]
# **Simple process the businesses dataset.**

# %%
def splitCategories(category_str):
  '''Function to convert cell in 'categories' column into a list of strings.'''

  #Split the string by commas.
  parts = category_str.split(', ')

  #List to store individual words.
  wordList = []

  for part in parts:
    #wordList.extend(part.split(' '))
    words = part.strip().split(' ')
    wordList.extend(word.strip("()") for word in words)

  #Speical cases like 'Naturopathic/Holistic'.
  wordList = [word.split('/') if '/' in word else word for word in wordList]
  #Special cases. For ex: 'Coffee&Tea'.
  wordList = [word for word in wordList if word not in ('&', '/')]
  return wordList

# %%
businessData = df_businesses.copy()
businessData['categories'] = businessData['categories'].astype(str)
businessData['categories'] = businessData['categories'].apply(splitCategories)

# %%
businessData.head(5)
# Out:
#    Unnamed: 0             business_id                      name  \
# 0           0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1           1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2           2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3           3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4           4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  [Doctors, Traditional, Chinese, Medicine, [Nat...
# 1  [Shipping, Centers, Local, Services, Notaries,...
# 2  [Department, Stores, Shopping, Fashion, Home, ...
# 3  [Restaurants, Food, Bubble, Tea, Coffee, Tea, ...
# 4                        [Brewpubs, Breweries, Food]
#
#                                                hours
# 0                                                NaN
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %% [markdown]
# **Generate filtered data based on user's query.**

# %%
def filteredData(text, data = businessData):
  '''Data filtering based on user's query. Derived from Task 1, without using 'Best' logic.'''

  #Tokenizing query text.
  doc = nlp(text)
  tokenList = process_text(text)
  tokenList = [token.capitalize() for token in tokenList]
  pattern = r"'(.*?)'"
  placeName = re.findall(pattern, text)

  #List to store city names: If user ask for multiple cities.
  cityList = []

  #Extract city.
  for ent in doc.ents:
    #Identify the text as locations.
    if ent.label_ =="GPE":
      cityList.append(ent.text)

  #Extract establishment name from query text.
  if placeName:
    placeName = placeName[0]

  #Extract categories list of the establishment name.
  if placeName:
    categories = businessData[businessData["name"] == placeName]['categories']
    categories = [item for sublist in categories for item in sublist]
  #If user not enter, empty.
  else:
    categories = []

  #---Compile the filtered dataset.---

  #If user did put a benchmark establishment.
  if categories:
    #Must match at least 3 categories of benchmarking establishment.
    filteredData = businessData[businessData['categories'].apply(lambda x: sum(category in x for category in categories) >= 3)]

    #Tokens in user query text, extra layer.
    mask = pd.Series(False, index=filteredData.index)
    for token in tokenList:
      mask = mask | filteredData['categories'].apply(lambda categories: any(token in category for category in categories))

      #Filter the DataFrame based on mask.
      filteredData_final = filteredData[mask]

  #If user did NOT put a benchmark establishment.
  else:
    #Use tokens in user query text for filtering.
    mask = pd.Series(False, index=businessData.index)
    for token in tokenList:
      mask = mask | businessData['categories'].apply(lambda categories: any(token in category for category in categories))
      filteredData_final = businessData[mask]

  #If user also put recommended cities.
  if len(cityList) == 0:
    return filteredData_final[["business_id", "name", "stars", "categories", "city"]]
  else:
    #Filter the DataFrame based on city names.
    filteredData_final = filteredData_final[filteredData_final["city"].isin(cityList)]
    return filteredData_final[["business_id", "name", "stars", "categories", "city"]]

# %% [markdown]
# **Test code for filterdData function.**

# %%
res = filteredData("Give me hair salons recommendation that like 'The Waxing Queen Of Tucson' in Tucson", businessData)
display(res.head(5))
# Out:
#                 business_id                             name  stars  \
# 173  E-nhxuu3zbt02oCj_1AFng                            Selah    5.0
# 233  h_3oLlQ_CFohwlzsrSZ6xQ       The Waxing Queen Of Tucson    4.5
# 295  YG0OOMLP3MWYPKHpkA_mew                        S&K Salon    4.0
# 478  fCRGXD-TTLgNhaC4mVFFJQ  El Con Health & Wellness Center    4.5
# 763  1gVkgLjul7xSIsJRCZHhmg        Straight Edge Barber Shop    4.0
#
#                                             categories    city
# 173  [Waxing, Hair, Removal, Skin, Care, Eyelash, S...  Tucson
# 233  [Beauty, Spas, Hair, Removal, Day, Spas, Skin,...  Tucson
# 295  [Men's, Hair, Salons, Waxing, Hair, Salons, Sk...  Tucson
# 478  [Beauty, Spas, Nutritionists, Medical, Spas, L...  Tucson
# 763  [Professional, Services, Men's, Hair, Salons, ...  Tucson

# %%
def computeRecommendation(query, df=business_train):
  '''Function to get top recommendations.'''

  #Get the filtered data.
  city_df = filteredData(query)

  #Text process the query.
  clean_query = process_text(query)

  #Get the mean embedding for the query.
  mean_query = compute_mean_embedding(clean_query, glove_embeddings)

  #Get only data that are common in the business data and the filtered data.
  merged_df = pd.merge(df, city_df, on='business_id', how='inner')

  #Computing cosine manually.
  cosine_vals = []

  #Itereate through the merged data set.
  for i in range(len(merged_df)):
    #Get the embeddings.
    mean_business = merged_df["mean_embedding"].values[i]

    #Compute cosine similarity.
    cosine = np.dot(mean_query, mean_business) / (norm(mean_query) * norm(mean_business))

    #Store the similarity score to the list.
    cosine_vals.append(cosine)

  #Merging the new values to the merged df.
  merged_df["cosine_similarity"] = cosine_vals

  #Recommend restaurants based on the query and highest similarity score.
  sorted_df = merged_df.sort_values(by="cosine_similarity", ascending=False).reset_index()
  final_df = sorted_df[["name", "stars", "categories", "city"]]

  #If no cities then we return a print statement.
  if len(final_df) == 0:
    return f"There is no recommendations within those cities :/"
  else:
    #If we have a dataset then we return the recommendations.
    return final_df.head(5)

# %%
def geoRec(queryRes):
  '''Show recommendation as map.'''

  city = queryRes['city'].iloc[0]
  locData = queryRes.merge(businessData[['name', 'city', 'latitude', 'longitude']], on=['name', 'city'], how='left')

  #Tackle cases where same business name in differnt cities.
  filtered_locData = locData[locData['city'] == city]
  geolocator = Nominatim(user_agent="my_geocoder")

  #Get the latitude and longitude of the city.
  cityLocation = geolocator.geocode(city, timeout=None)
  cityLatitude, cityLongitude = cityLocation.latitude, cityLocation.longitude

  #Folium map using city as the center.
  mapCenter = [cityLatitude, cityLongitude]
  mapCity = folium.Map(location=mapCenter, zoom_start=12, width=700, height=500)

  #Add a marker for the city.
  folium.Marker(location=mapCenter, popup=f"City: {city}").add_to(mapCity)

  #Map each establishment in queryRes.
  for index, row in filtered_locData.iterrows():
    #Use respective latitude and longitude from businesses data.
    establishmentLocation = [row['latitude'], row['longitude']]
    folium.Marker(location=establishmentLocation, popup=row['name']).add_to(mapCity)

  display(mapCity)

# %% [markdown]
# ### **Query 1: "List sushi Japanese restaurants that are similar to 'Tuna Bar' in Santa Barbara."**

# %%
query1 = f"List sushi Japanese restaurants that are similar to 'Tuna Bar' in Santa Barbara"
query1res = computeRecommendation(query1)
print(f"Here are the recommendataions for the 1st query:")
display(query1res)
print('\n')
geoRec(query1res)
# Out:
# Here are the recommendataions for the 1st query:
#                               name  stars  \
# 0      Sakana Sushi Bar & Japanese    4.0
# 1                        Tsukemono    4.0
# 2  Hibachi Steak House & Sushi Bar    3.5
# 3                          Ichiban    3.5
# 4                         Yoichi's    4.5
#
#                                           categories           city
# 0               [Sushi, Bars, Japanese, Restaurants]  Santa Barbara
# 1               [Sushi, Bars, Japanese, Restaurants]  Santa Barbara
# 2  [Steakhouses, Sushi, Bars, Restaurants, Japanese]  Santa Barbara
# 3               [Restaurants, Japanese, Sushi, Bars]  Santa Barbara
# 4           [Restaurants, Nightlife, Japanese, Bars]  Santa Barbara
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c143f108151c4669a69b53101efe756e {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c143f108151c4669a69b53101efe756e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c143f108151c4669a69b53101efe756e = L.map(
#                 &quot;map_c143f108151c4669a69b53101efe756e&quot;,
#                 {
#                     center: [34.4221319, -119.702667],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4020e948da23c693cb041a16be992685 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c143f108151c4669a69b53101efe756e);
#
#
#             var marker_149818dfd9939cb3adb7c0ecac5a41f2 = L.marker(
#                 [34.4221319, -119.702667],
#                 {}
#             ).addTo(map_c143f108151c4669a69b53101efe756e);
#
#
#         var popup_4b2feca9b11988e17028770adee4724a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2f720dccc5a92c69b78316763d1fe58 = $(`&lt;div id=&quot;html_a2f720dccc5a92c69b78316763d1fe58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Santa Barbara&lt;/div&gt;`)[0];
#                 popup_4b2feca9b11988e17028770adee4724a.setContent(html_a2f720dccc5a92c69b78316763d1fe58);
#
#
#
#         marker_149818dfd9939cb3adb7c0ecac5a41f2.bindPopup(popup_4b2feca9b11988e17028770adee4724a)
#         ;
#
#
#
#
#             var marker_6612465d7620dbbb107eb9a414b24ac8 = L.marker(
#                 [34.422264, -119.650288],
#                 {}
#             ).addTo(map_c143f108151c4669a69b53101efe756e);
#
#
#         var popup_8d67400c623793cc67086425620afdcc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fbf77426e0004300c92a0c0212febb2f = $(`&lt;div id=&quot;html_fbf77426e0004300c92a0c0212febb2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sakana Sushi Bar &amp; Japanese&lt;/div&gt;`)[0];
#                 popup_8d67400c623793cc67086425620afdcc.setContent(html_fbf77426e0004300c92a0c0212febb2f);
#
#
#
#         marker_6612465d7620dbbb107eb9a414b24ac8.bindPopup(popup_8d67400c623793cc67086425620afdcc)
#         ;
#
#
#
#
#             var marker_3f2f11ffafb47b9b5a6cbaf6a7d9ffe9 = L.marker(
#                 [34.4220238853, -119.6987793784],
#                 {}
#             ).addTo(map_c143f108151c4669a69b53101efe756e);
#
#
#         var popup_2442b097fb5db2cbed5a1923aecba5f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b80167968e775f1f4aa2ec2a9ab4cc8e = $(`&lt;div id=&quot;html_b80167968e775f1f4aa2ec2a9ab4cc8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tsukemono&lt;/div&gt;`)[0];
#                 popup_2442b097fb5db2cbed5a1923aecba5f7.setContent(html_b80167968e775f1f4aa2ec2a9ab4cc8e);
#
#
#
#         marker_3f2f11ffafb47b9b5a6cbaf6a7d9ffe9.bindPopup(popup_2442b097fb5db2cbed5a1923aecba5f7)
#         ;
#
#
#
#
#             var marker_cfebdb45cf31ab362fe5aa8d81b69569 = L.marker(
#                 [34.4169836, -119.6955563],
#                 {}
#             ).addTo(map_c143f108151c4669a69b53101efe756e);
#
#
#         var popup_b11961963f01dade5861c4c92d46b20e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d67db464f963c222cf23f59d0c414563 = $(`&lt;div id=&quot;html_d67db464f963c222cf23f59d0c414563&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hibachi Steak House &amp; Sushi Bar&lt;/div&gt;`)[0];
#                 popup_b11961963f01dade5861c4c92d46b20e.setContent(html_d67db464f963c222cf23f59d0c414563);
#
#
#
#         marker_cfebdb45cf31ab362fe5aa8d81b69569.bindPopup(popup_b11961963f01dade5861c4c92d46b20e)
#         ;
#
#
#
#
#             var marker_20c3f5fd65ccdcaec0e64febaa62095f = L.marker(
#                 [34.4017849, -119.720842],
#                 {}
#             ).addTo(map_c143f108151c4669a69b53101efe756e);
#
#
#         var popup_9b7d7efd322d5dd5cf4737fda645e50d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad19f2aa2c92b8cfe645997978085557 = $(`&lt;div id=&quot;html_ad19f2aa2c92b8cfe645997978085557&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ichiban&lt;/div&gt;`)[0];
#                 popup_9b7d7efd322d5dd5cf4737fda645e50d.setContent(html_ad19f2aa2c92b8cfe645997978085557);
#
#
#
#         marker_20c3f5fd65ccdcaec0e64febaa62095f.bindPopup(popup_9b7d7efd322d5dd5cf4737fda645e50d)
#         ;
#
#
#
#
#             var marker_0c6a093f8c1a4e51844fe0e3891fef7a = L.m

# %% [markdown]
# ### **Query 2: "Give me IV Hydration spas recommendation in Nashville that similar to '61Five Health & Wellness."**

# %%
query2 = f"Give me IV Hydration spas recommendation in Nashville that similar to '61Five Health & Wellness'"
query2res = computeRecommendation(query2)
print(f"Here is the recommendations for the 2nd query:")
display(query2res)
print('\n')
geoRec(query2res)
# Out:
# Here is the recommendations for the 2nd query:
#                               name  stars  \
# 0                        Supercuts    3.0
# 1          Green Hills Barber Shop    4.0
# 2           Irene's Spa & Wellness    5.0
# 3  Tina's Salon For Nails and Hair    4.0
# 4                   Studio 1 Nails    3.0
#
#                                           categories       city
# 0  [Men's, Hair, Salons, Cosmetics, Beauty, Suppl...  Nashville
# 1  [Hair, Salons, Dry, Cleaning, Laundry, Hair, S...  Nashville
# 2  [Beauty, Spas, Skin, Care, Waxing, Day, Spas, ...  Nashville
# 3         [Nail, Salons, Beauty, Spas, Hair, Salons]  Nashville
# 4                       [Nail, Salons, Beauty, Spas]  Nashville
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3 = L.map(
#                 &quot;map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3&quot;,
#                 {
#                     center: [36.1622767, -86.7742984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07186f88f39467bce0780172bd53b5f2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3);
#
#
#             var marker_907bfe254fa1bff3a960dae887146922 = L.marker(
#                 [36.1622767, -86.7742984],
#                 {}
#             ).addTo(map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3);
#
#
#         var popup_7721532792b1ec7956dea6a8c9da16b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27663dc98e6f04987aa7865f38a099af = $(`&lt;div id=&quot;html_27663dc98e6f04987aa7865f38a099af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Nashville&lt;/div&gt;`)[0];
#                 popup_7721532792b1ec7956dea6a8c9da16b1.setContent(html_27663dc98e6f04987aa7865f38a099af);
#
#
#
#         marker_907bfe254fa1bff3a960dae887146922.bindPopup(popup_7721532792b1ec7956dea6a8c9da16b1)
#         ;
#
#
#
#
#             var marker_bacef3bc0edd258aa80823140e88bd9c = L.marker(
#                 [36.039511, -86.74130099999999],
#                 {}
#             ).addTo(map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3);
#
#
#         var popup_fb023036256d8a7cb7ddbe97fc0285bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2d08e4ba9bca760f600f0888e332b89 = $(`&lt;div id=&quot;html_b2d08e4ba9bca760f600f0888e332b89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supercuts&lt;/div&gt;`)[0];
#                 popup_fb023036256d8a7cb7ddbe97fc0285bb.setContent(html_b2d08e4ba9bca760f600f0888e332b89);
#
#
#
#         marker_bacef3bc0edd258aa80823140e88bd9c.bindPopup(popup_fb023036256d8a7cb7ddbe97fc0285bb)
#         ;
#
#
#
#
#             var marker_af04db690a3f2d7ba1d40e3aabc0e4a4 = L.marker(
#                 [36.148067, -86.665566],
#                 {}
#             ).addTo(map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3);
#
#
#         var popup_efde1742f9caa5fc834560b6f9a71ffa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ce14914e627fe6d311f24504fbc1d34 = $(`&lt;div id=&quot;html_4ce14914e627fe6d311f24504fbc1d34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supercuts&lt;/div&gt;`)[0];
#                 popup_efde1742f9caa5fc834560b6f9a71ffa.setContent(html_4ce14914e627fe6d311f24504fbc1d34);
#
#
#
#         marker_af04db690a3f2d7ba1d40e3aabc0e4a4.bindPopup(popup_efde1742f9caa5fc834560b6f9a71ffa)
#         ;
#
#
#
#
#             var marker_a20f7c39747a2a362a10c1072cfffc9a = L.marker(
#                 [36.145957, -86.799193],
#                 {}
#             ).addTo(map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3);
#
#
#         var popup_daf2506013b1b002444ac169c5e12dd3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d84a7c4e24798e079d7976adb0541cb = $(`&lt;div id=&quot;html_6d84a7c4e24798e079d7976adb0541cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supercuts&lt;/div&gt;`)[0];
#                 popup_daf2506013b1b002444ac169c5e12dd3.setContent(html_6d84a7c4e24798e079d7976adb0541cb);
#
#
#
#         marker_a20f7c39747a2a362a10c1072cfffc9a.bindPopup(popup_daf2506013b1b002444ac169c5e12dd3)
#         ;
#
#
#
#
#             var marker_627fa726676f9b226a382b82d05f7462 = L.marker(
#                 [36.083428, -86.64882],
#                 {}
#             ).addTo(map_1bb584bd2c5cb70c3f1b4aa9a3b8c8f3);
#
#
#         var popup_8b6432914c55c62e65762f6144bb4e1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a672bb1d3f4f5a93325974b4425fb516 = $(`&lt;div id=&quot;html_a672bb1d3f4f5a93325974b4425fb516&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Supercuts&lt;/div&gt;`)[0];
#                 popup_8b6432914c55c62e65762f6144bb4e1e.setContent(html_a672bb1d3f4f5a93325974b4425fb516);
#
#
#
#         marker_627fa726676f9b226a382b82d05f7462.bindPopup(popup_8b6432914c55c62e65762f6144bb4e1e)
#         ;
#
#
#
#
#             var marker_baf92d1a56bc311fa5c13bd0a953407b = L.marker(
#                 [36.1020621582, -86.8167703405],

# %% [markdown]
# ### **Query 3: "Show me apartments complex like 'Ridge Carlton Apartments' in Indianapolis."**

# %%
#Only 3 locations satisify/
query3 = f"Show me apartments complex like 'Ridge Carlton Apartments' in Indianapolis"
query3res = computeRecommendation(query3)
print(f"Here is the recommendations for the 3rd query:")
display(query3res)
print('\n')
geoRec(query3res)
# Out:
# Here is the recommendations for the 3rd query:
#                                                 name  stars  \
# 0                                 Scandia Apartments    2.0
# 1  Oak Lake At Crooked Creek Apartments by J.C. Hart    1.5
# 2                                      Carlyle Court    2.5
#
#                                           categories          city
# 0         [Home, Services, Real, Estate, Apartments]  Indianapolis
# 1         [Apartments, Home, Services, Real, Estate]  Indianapolis
# 2  [Real, Estate, Services, Home, Services, Real,...  Indianapolis
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9d9d355958819e6db6a20f6cbdfd47c {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9d9d355958819e6db6a20f6cbdfd47c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9d9d355958819e6db6a20f6cbdfd47c = L.map(
#                 &quot;map_f9d9d355958819e6db6a20f6cbdfd47c&quot;,
#                 {
#                     center: [39.7683331, -86.1583502],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b02174be8ff5b92184fcef5bae84cd9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f9d9d355958819e6db6a20f6cbdfd47c);
#
#
#             var marker_0b13b5ae9b422dc8595e093fdcda67b0 = L.marker(
#                 [39.7683331, -86.1583502],
#                 {}
#             ).addTo(map_f9d9d355958819e6db6a20f6cbdfd47c);
#
#
#         var popup_a71c45d91f6fef38e55c4fbd03536843 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_164cf0d0d6d90702707f199ae6d1ba31 = $(`&lt;div id=&quot;html_164cf0d0d6d90702707f199ae6d1ba31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Indianapolis&lt;/div&gt;`)[0];
#                 popup_a71c45d91f6fef38e55c4fbd03536843.setContent(html_164cf0d0d6d90702707f199ae6d1ba31);
#
#
#
#         marker_0b13b5ae9b422dc8595e093fdcda67b0.bindPopup(popup_a71c45d91f6fef38e55c4fbd03536843)
#         ;
#
#
#
#
#             var marker_1da701cd9ee689198bac677b7c5072b5 = L.marker(
#                 [39.9229874331, -86.0710871461],
#                 {}
#             ).addTo(map_f9d9d355958819e6db6a20f6cbdfd47c);
#
#
#         var popup_c9c7bf64dfab321b5ef5d127cbe465c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3707dd2924509e7c8d27ba7a5bc17529 = $(`&lt;div id=&quot;html_3707dd2924509e7c8d27ba7a5bc17529&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Scandia Apartments&lt;/div&gt;`)[0];
#                 popup_c9c7bf64dfab321b5ef5d127cbe465c8.setContent(html_3707dd2924509e7c8d27ba7a5bc17529);
#
#
#
#         marker_1da701cd9ee689198bac677b7c5072b5.bindPopup(popup_c9c7bf64dfab321b5ef5d127cbe465c8)
#         ;
#
#
#
#
#             var marker_b22a91a1f6a82fdd41e4426d928477b9 = L.marker(
#                 [39.9114682, -86.2332179],
#                 {}
#             ).addTo(map_f9d9d355958819e6db6a20f6cbdfd47c);
#
#
#         var popup_4b38b4481a46158c62654c569d742a03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_235f3d47566cfd47eddd6542818c2902 = $(`&lt;div id=&quot;html_235f3d47566cfd47eddd6542818c2902&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Oak Lake At Crooked Creek Apartments by J.C. Hart&lt;/div&gt;`)[0];
#                 popup_4b38b4481a46158c62654c569d742a03.setContent(html_235f3d47566cfd47eddd6542818c2902);
#
#
#
#         marker_b22a91a1f6a82fdd41e4426d928477b9.bindPopup(popup_4b38b4481a46158c62654c569d742a03)
#         ;
#
#
#
#
#             var marker_b0d115f65c53b1e91976e79b4f19c98a = L.marker(
#                 [39.9254707, -86.1421444],
#                 {}
#             ).addTo(map_f9d9d355958819e6db6a20f6cbdfd47c);
#
#
#         var popup_b9f4c48594b3795813cef26a41faaf61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8eee39a05c8a5965d2a919a4abb7937e = $(`&lt;div id=&quot;html_8eee39a05c8a5965d2a919a4abb7937e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Carlyle Court&lt;/div&gt;`)[0];
#                 popup_b9f4c48594b3795813cef26a41faaf61.setContent(html_8eee39a05c8a5965d2a919a4abb7937e);
#
#
#
#         marker_b0d115f65c53b1e91976e79b4f19c98a.bindPopup(popup_b9f4c48594b3795813cef26a41faaf61)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### **Query 4: "Give me recommendation like 'Vintage Bar and Grill' in Tampa."**

# %%
query4 = f"Give me recommendation like 'Vintage Bar and Grill' in Tampa"
query4res = computeRecommendation(query4)
print(f"Here is the recommendations for the 4th query:")
display(query4res)
print('\n')
geoRec(query4res)
# Out:
# Here is the recommendations for the 4th query:
#                                   name  stars  \
# 0  Scores Gentlemens Club & Steakhouse    2.5
# 1                   The Gasparilla Bar    3.5
# 2                        Twisted Olive    3.5
# 3                    Four Green Fields    4.5
# 4                              Chili's    2.0
#
#                                           categories   city
# 0  [Lounges, Adult, Entertainment, Bars, Champagn...  Tampa
# 1                                  [Bars, Nightlife]  Tampa
# 2                     [Piano, Bars, Bars, Nightlife]  Tampa
# 3  [Irish, Pub, Bars, Restaurants, Irish, Nightlife]  Tampa
# 4  [Chicken, Wings, Bars, Restaurants, Nightlife,...  Tampa
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84571d22783d267b34d78fc8468016d3 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84571d22783d267b34d78fc8468016d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84571d22783d267b34d78fc8468016d3 = L.map(
#                 &quot;map_84571d22783d267b34d78fc8468016d3&quot;,
#                 {
#                     center: [27.9477595, -82.458444],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00f3a7b14361343a4ed5adb79e88b554 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_84571d22783d267b34d78fc8468016d3);
#
#
#             var marker_bb77614f0c7e3f365e37320d8fb1d7fc = L.marker(
#                 [27.9477595, -82.458444],
#                 {}
#             ).addTo(map_84571d22783d267b34d78fc8468016d3);
#
#
#         var popup_c4f9b46c550a9cfc902b98f747e857a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d4feffd222c6594a783da41cf6d911c = $(`&lt;div id=&quot;html_9d4feffd222c6594a783da41cf6d911c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Tampa&lt;/div&gt;`)[0];
#                 popup_c4f9b46c550a9cfc902b98f747e857a8.setContent(html_9d4feffd222c6594a783da41cf6d911c);
#
#
#
#         marker_bb77614f0c7e3f365e37320d8fb1d7fc.bindPopup(popup_c4f9b46c550a9cfc902b98f747e857a8)
#         ;
#
#
#
#
#             var marker_843467304340415725dae753fa6043c8 = L.marker(
#                 [27.9620343, -82.5060203],
#                 {}
#             ).addTo(map_84571d22783d267b34d78fc8468016d3);
#
#
#         var popup_f8b5628f4bbba862c31cabb0d7e5ef48 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03a7da9344daf4cd9ea87f3c54b71efe = $(`&lt;div id=&quot;html_03a7da9344daf4cd9ea87f3c54b71efe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Scores Gentlemens Club &amp; Steakhouse&lt;/div&gt;`)[0];
#                 popup_f8b5628f4bbba862c31cabb0d7e5ef48.setContent(html_03a7da9344daf4cd9ea87f3c54b71efe);
#
#
#
#         marker_843467304340415725dae753fa6043c8.bindPopup(popup_f8b5628f4bbba862c31cabb0d7e5ef48)
#         ;
#
#
#
#
#             var marker_58cf6c3ce0d450d1ce980bd6dadb70fd = L.marker(
#                 [27.977399889, -82.5376345217],
#                 {}
#             ).addTo(map_84571d22783d267b34d78fc8468016d3);
#
#
#         var popup_a40f2ca33247820807b124310b2de7f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_314841085575ebd1d086e6c9b4b51596 = $(`&lt;div id=&quot;html_314841085575ebd1d086e6c9b4b51596&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Gasparilla Bar&lt;/div&gt;`)[0];
#                 popup_a40f2ca33247820807b124310b2de7f8.setContent(html_314841085575ebd1d086e6c9b4b51596);
#
#
#
#         marker_58cf6c3ce0d450d1ce980bd6dadb70fd.bindPopup(popup_a40f2ca33247820807b124310b2de7f8)
#         ;
#
#
#
#
#             var marker_99e523791917e63ce1ccbe11f164390c = L.marker(
#                 [28.044101, -82.5965001],
#                 {}
#             ).addTo(map_84571d22783d267b34d78fc8468016d3);
#
#
#         var popup_2df7c247381804e590da5255998b42a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e548b3bea0713680887e5e097103ff14 = $(`&lt;div id=&quot;html_e548b3bea0713680887e5e097103ff14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Twisted Olive&lt;/div&gt;`)[0];
#                 popup_2df7c247381804e590da5255998b42a0.setContent(html_e548b3bea0713680887e5e097103ff14);
#
#
#
#         marker_99e523791917e63ce1ccbe11f164390c.bindPopup(popup_2df7c247381804e590da5255998b42a0)
#         ;
#
#
#
#
#             var marker_8d7037a3d6331930ae6d959a9009b125 = L.marker(
#                 [27.9803985924, -82.5377866183],
#                 {}
#             ).addTo(map_84571d22783d267b34d78fc8468016d3);
#
#
#         var popup_64f60837678f88646c33164b4699a1f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8419c29950b94b274b46fade6df2c065 = $(`&lt;div id=&quot;html_8419c29950b94b274b46fade6df2c065&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Four Green Fields&lt;/div&gt;`)[0];
#                 popup_64f60837678f88646c33164b4699a1f9.setContent(html_8419c29950b94b274b46fade6df2c065);
#
#
#
#         marker_8d7037a3d6331930ae6d959a9009b125.bindPopup(popup_64f60837678f88646c33164b4699a1f9)
#         ;
#
#
#
#
#             var marker_5534752bff7af061f053f30b5a0b0ad9 = L.mar

# %% [markdown]
# ### **Query 5: "Give me hair salons recommendation that like 'The Waxing Queen Of Tucson' in New Orleans."**

# %%
query5 = f"Give me hair salons recommendation that like 'The Waxing Queen Of Tucson' in New Orleans"
query5res = computeRecommendation(query5)
print(f"Here is the recommendations for the 5th query:")
display(query5res)
print('\n')
geoRec(query5res)
# Out:
# Here is the recommendations for the 5th query:
#                                 name  stars  \
# 0                          Lee Nails    4.0
# 1                                WAX    4.5
# 2                    John Jay Salons    3.5
# 3  The Ritz-Carlton Spa, New Orleans    4.0
# 4              Pamper & Polish Nails    2.5
#
#                                           categories         city
# 0              [Nail, Salons, Massage, Beauty, Spas]  New Orleans
# 1  [Hair, Removal, Skin, Care, Waxing, Beauty, Spas]  New Orleans
# 2                       [Beauty, Spas, Hair, Salons]  New Orleans
# 3  [Beauty, Spas, Restaurants, Hotels, Event, Pla...  New Orleans
# 4  [Eyebrow, Services, Beauty, Spas, Nail, Salons...  New Orleans
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67d0e8a8470d2b5cf50f930b5b9898c7 {
#                     position: relative;
#                     width: 700.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67d0e8a8470d2b5cf50f930b5b9898c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67d0e8a8470d2b5cf50f930b5b9898c7 = L.map(
#                 &quot;map_67d0e8a8470d2b5cf50f930b5b9898c7&quot;,
#                 {
#                     center: [29.9759983, -90.0782127],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_843f9a5f6b0380ac07453db8d9ce2214 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_67d0e8a8470d2b5cf50f930b5b9898c7);
#
#
#             var marker_b144b8a7faa98e16dd842d468bc63cb1 = L.marker(
#                 [29.9759983, -90.0782127],
#                 {}
#             ).addTo(map_67d0e8a8470d2b5cf50f930b5b9898c7);
#
#
#         var popup_5b4b70d9ddbf84c4d7534764e079c52f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f4cd2f3feeb709455d645ad2ee16e18 = $(`&lt;div id=&quot;html_1f4cd2f3feeb709455d645ad2ee16e18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: New Orleans&lt;/div&gt;`)[0];
#                 popup_5b4b70d9ddbf84c4d7534764e079c52f.setContent(html_1f4cd2f3feeb709455d645ad2ee16e18);
#
#
#
#         marker_b144b8a7faa98e16dd842d468bc63cb1.bindPopup(popup_5b4b70d9ddbf84c4d7534764e079c52f)
#         ;
#
#
#
#
#             var marker_9f183e3efc92041ccb5d7b978e644f2a = L.marker(
#                 [29.9668179, -90.0909038],
#                 {}
#             ).addTo(map_67d0e8a8470d2b5cf50f930b5b9898c7);
#
#
#         var popup_43a8d3254bf5e106cf90c513b95104b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10b1ca5760ed0c032cf1c63cfb3722ad = $(`&lt;div id=&quot;html_10b1ca5760ed0c032cf1c63cfb3722ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lee Nails&lt;/div&gt;`)[0];
#                 popup_43a8d3254bf5e106cf90c513b95104b5.setContent(html_10b1ca5760ed0c032cf1c63cfb3722ad);
#
#
#
#         marker_9f183e3efc92041ccb5d7b978e644f2a.bindPopup(popup_43a8d3254bf5e106cf90c513b95104b5)
#         ;
#
#
#
#
#             var marker_724ddcdcad7cbaa333ad9cd146dc53b4 = L.marker(
#                 [29.9594384, -90.0632968],
#                 {}
#             ).addTo(map_67d0e8a8470d2b5cf50f930b5b9898c7);
#
#
#         var popup_74000cc43a1782336911fede9a9dc114 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20b9e7f7cbfc09e6a0485192ddc15469 = $(`&lt;div id=&quot;html_20b9e7f7cbfc09e6a0485192ddc15469&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WAX&lt;/div&gt;`)[0];
#                 popup_74000cc43a1782336911fede9a9dc114.setContent(html_20b9e7f7cbfc09e6a0485192ddc15469);
#
#
#
#         marker_724ddcdcad7cbaa333ad9cd146dc53b4.bindPopup(popup_74000cc43a1782336911fede9a9dc114)
#         ;
#
#
#
#
#             var marker_e8198a0532dcfe7c4c1ad6fa7ba1e81f = L.marker(
#                 [29.9398195, -90.1303899],
#                 {}
#             ).addTo(map_67d0e8a8470d2b5cf50f930b5b9898c7);
#
#
#         var popup_587092e6cc592e029bcf7b1be49c0300 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2774edb4ba8341e8d7aa8bd7d384a16 = $(`&lt;div id=&quot;html_b2774edb4ba8341e8d7aa8bd7d384a16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;John Jay Salons&lt;/div&gt;`)[0];
#                 popup_587092e6cc592e029bcf7b1be49c0300.setContent(html_b2774edb4ba8341e8d7aa8bd7d384a16);
#
#
#
#         marker_e8198a0532dcfe7c4c1ad6fa7ba1e81f.bindPopup(popup_587092e6cc592e029bcf7b1be49c0300)
#         ;
#
#
#
#
#             var marker_1a99c6f0957d2bcfc882a079b3874f21 = L.marker(
#                 [29.9550178, -90.0709905],
#                 {}
#             ).addTo(map_67d0e8a8470d2b5cf50f930b5b9898c7);
#
#
#         var popup_37648fab5769d61af177195df41f49fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2faa28b4e7a109ba849f8ab7f451828d = $(`&lt;div id=&quot;html_2faa28b4e7a109ba849f8ab7f451828d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Ritz-Carlton Spa, New Orleans&lt;/div&gt;`)[0];
#                 popup_37648fab5769d61af177195df41f49fa.setContent(html_2faa28b4e7a109ba849f8ab7f451828d);
#
#
#
#         marker_1a99c6f0957d2bcfc882a079b3874f21.bindPopup(popup_37648fab5769d61af177195df41f49fa)
#         ;
#
#
#
#
#             var marker_9fd18149ae0bf6ab99b8da7c97af73b8 = L.marker(
#                 [30.0284

# %%
# !jupyter nbconvert --to html CSC575-Final-Project-Task2_3.ipynb
# Out:
# [NbConvertApp] Converting notebook CSC575-Final-Project-Task2_3.ipynb to html
# [NbConvertApp] Writing 871512 bytes to CSC575-Final-Project-Task2_3.html
